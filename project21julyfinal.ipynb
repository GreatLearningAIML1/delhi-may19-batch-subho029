# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('/content/drive/My Drive/Colab Notebooks/project21july/Laliga.csv')

# %%
data
# Out:
#     Pos                 Team  Seasons  ...    Debut Since/LastApp BestPosition
# 0     1          Real Madrid       86  ...     1929          1929            1
# 1     2            Barcelona       86  ...     1929          1929            1
# 2     3      Atletico Madrid       80  ...     1929       2002-03            1
# 3     4             Valencia       82  ...  1931-32       1987-88            1
# 4     5      Athletic Bilbao       86  ...     1929          1929            1
# 5     6              Sevilla       73  ...  1934-35       2001-02            1
# 6     7             Espanyol       82  ...     1929       1994-95            3
# 7     8        Real Sociedad       70  ...     1929       2010-11            1
# 8     9             Zaragoza       58  ...  1939-40       2012-13            2
# 9    10           Real Betis       51  ...  1932-33       2015-16            1
# 10   11  Deportivo La Coruna       45  ...  1941-42       2014-15            1
# ...

# %%
data=data.replace('-', 0) 
print(data_replace)
#replace dashes with 0 to make sure you can perform arithmetic operations on the data
# Out:
#     Pos                 Team  Seasons  ... BestPosition DebutFirst DebutSecond
# 0     1          Real Madrid       86  ...            1       1929        None
# 1     2            Barcelona       86  ...            1       1929        None
# 2     3      Atletico Madrid       80  ...            1       1929        None
# 3     4             Valencia       82  ...            1       1931          32
# 4     5      Athletic Bilbao       86  ...            1       1929        None
# 5     6              Sevilla       73  ...            1       1934          35
# 6     7             Espanyol       82  ...            3       1929        None
# 7     8        Real Sociedad       70  ...            1       1929        None
# 8     9             Zaragoza       58  ...            2       1939          40
# 9    10           Real Betis       51  ...            1       1932          33
# 10   11  Deportivo La Coruna       45  ...            1       1941          42
# ...

# %%
new = data_replace["Debut"].str.split("-", n = 1, expand = True) 
data_replace["DebutFirst"]= new[0]
data_replace["DebutSecond"]= new[1]

# %%
data_replace
# Out:
#     Pos                 Team  Seasons  ... BestPosition DebutFirst DebutSecond
# 0     1          Real Madrid       86  ...            1       1929        None
# 1     2            Barcelona       86  ...            1       1929        None
# 2     3      Atletico Madrid       80  ...            1       1929        None
# 3     4             Valencia       82  ...            1       1931          32
# 4     5      Athletic Bilbao       86  ...            1       1929        None
# 5     6              Sevilla       73  ...            1       1934          35
# 6     7             Espanyol       82  ...            3       1929        None
# 7     8        Real Sociedad       70  ...            1       1929        None
# 8     9             Zaragoza       58  ...            2       1939          40
# 9    10           Real Betis       51  ...            1       1932          33
# 10   11  Deportivo La Coruna       45  ...            1       1941          42
# ...

# %%
Debute_Data= data_replace.loc[(data_replace['DebutFirst'] > '1930') & (data_replace['DebutFirst'] < '1980') & (data_replace['DebutSecond'] < '80')]

# %%
Debute_Data
#output of the teams which have started playing between 1930-1980
# Out:
#     Pos                 Team  Seasons  ... BestPosition DebutFirst DebutSecond
# 3     4             Valencia       82  ...            1       1931          32
# 5     6              Sevilla       73  ...            1       1934          35
# 8     9             Zaragoza       58  ...            2       1939          40
# 9    10           Real Betis       51  ...            1       1932          33
# 10   11  Deportivo La Coruna       45  ...            1       1941          42
# 11   12           Celta Vigo       51  ...            4       1939          40
# 12   13           Valladolid       42  ...            4       1948          49
# 14   15       Sporting Gijon       43  ...            2       1944          45
# 15   16              Osasuna       37  ...            4       1935          36
# 16   17               Malaga       36  ...            4       1949          50
# 17   18               Oviedo       38  ...            3       1933          34
# ...

# %%
data.sort_values('Points', inplace=True, ascending=True )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-a798c8171df8> in <module>()
# ----> 1 data.sort_values('Points', inplace=True, ascending=True )
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4723
#    4724             indexer = nargsort(k, kind=kind, ascending=ascending,
# -> 4725                                na_position=na_position)
#    4726
#    4727         new_data = self._data.take(indexer,
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/sorting.py in nargsort(items, kind, ascending, na_position)
#     271         non_nans = non_nans[::-1]
#     272         non_nan_idx = non_nan_idx[::-1]
# --> 273     indexer = non_nan_idx[non_nans.argsort(kind=kind)]
#     274     if not ascending:
#     275         indexer = indexer[::-1]
#
# ...

# %%
data_replace[:5]
#list of teams which came Top 5 in terms of points
# Out:
#    Pos             Team  Seasons  ... BestPosition DebutFirst DebutSecond
# 0    1      Real Madrid       86  ...            1       1929        None
# 1    2        Barcelona       86  ...            1       1929        None
# 2    3  Atletico Madrid       80  ...            1       1929        None
# 3    4         Valencia       82  ...            1       1931          32
# 4    5  Athletic Bilbao       86  ...            1       1929        None
#
# [5 rows x 22 columns]

# %%
data=data.replace('-', 0) 
#replace dashes with 0 to make sure you can perform arithmetic operations on the data

# %%
data['GoalsAgainst'] =data['GoalsAgainst'].astype(int)
data['GoalsFor'] =data['GoalsFor'].astype(int)
data['GamesPlayed'] =data['GamesPlayed'].astype(int)
data['GamesWon'] =data['GamesWon'].astype(int)
data['Points'] =data['Points'].astype(int)

# %%
data['Goal_diff_count'] = data['GoalsFor'] - data['GoalsAgainst'] 

#output of Goal_diff_count = GoalsFor - GoalsAgainst

# %%
data
# Out:
#     Pos                 Team  ...  BestPosition  Goal_diff_count
# 0     1          Real Madrid  ...             1             2807
# 1     2            Barcelona  ...             1             2786
# 2     3      Atletico Madrid  ...             1             1225
# 3     4             Valencia  ...             1              929
# 4     5      Athletic Bilbao  ...             1              931
# 5     6              Sevilla  ...             1              307
# 6     7             Espanyol  ...             3             -280
# 7     8        Real Sociedad  ...             1               -2
# 8     9             Zaragoza  ...             2             -164
# 9    10           Real Betis  ...             1             -333
# 10   11  Deportivo La Coruna  ...             1             -136
# 11   12           Celta Vigo  ...             4             -346
# 12   13           Valladolid  ...             4             -413
# ...

# %%
print(data.dtypes)
# Out:
# Pos                 int64
# Team               object
# Seasons             int64
# Points              int64
# GamesPlayed         int64
# GamesWon            int64
# GamesDrawn         object
# GamesLost          object
# GoalsFor            int64
# GoalsAgainst        int64
# Champion           object
# Runner-up          object
# Third              object
# Fourth             object
# Fifth              object
# Sixth              object
# T                  object
# Debut              object
# Since/LastApp      object
# BestPosition        int64
# Goal_diff_count     int64
# dtype: object

# %%
Gaoldiffmax = data.groupby(['Team'])['Goal_diff_count'].max()

# %%
Gaoldiffmax
# Out:
# Team
# AD Almeria              -45
# Alaves                 -165
# Albacete                -90
# Alcoyano               -107
# Almeria                -122
# Arenas                  -81
# Athletic Bilbao         931
# Atletico Madrid        1225
# Atletico Tetuan         -34
# Barcelona              2786
# Burgos CF               -94
# Cadiz                  -269
# Castellon              -169
# Celta Vigo             -346
# Compostela              -42
# Condal                  -20
# Cordoba                -145
# Cultural Leonesa        -31
# Deportivo La Coruna    -136
# Eibar                   -28
# Elche                  -272
# Espanyol               -280
# Europa                  -34
# Extremadura             -55
# Getafe                 -113
# Gimnastic              -114
# Girona                    0
# Granada                -338
# Hercules               -334
# Jaen                    -62
#                        ...
# Leganes                 -19
# Levante                -202
# ...

# %%
data[data['Goal_diff_count']==data['Goal_diff_count'].max()]

#the team which has maximum  goal difference
# Out:
#    Pos         Team  Seasons  ...  Since/LastApp  BestPosition  Goal_diff_count
# 0    1  Real Madrid       86  ...           1929             1             2807
#
# [1 rows x 21 columns]

# %%
data[data['Goal_diff_count']==data['Goal_diff_count'].min()]

#the team which has minimum  goal difference
# Out:
#     Pos              Team  Seasons  ...  Since/LastApp  BestPosition  Goal_diff_count
# 13   14  Racing Santander       44  ...        2011-12             2             -525
#
# [1 rows x 21 columns]

# %%
data['WinningPct'] = data['GamesWon']/data['GamesPlayed'].sum()

#Percentage of Winning = (GamesWon / GamesPlayed)*100

# %%
data
# Out:
#     Pos                 Team  ...  Goal_diff_count  WinningPct
# 0     1          Real Madrid  ...             2807    0.033885
# 1     2            Barcelona  ...             2786    0.032527
# 2     3      Atletico Madrid  ...             1225    0.025532
# 3     4             Valencia  ...              929    0.024421
# 4     5      Athletic Bilbao  ...              931    0.024873
# 5     6              Sevilla  ...              307    0.020368
# 6     7             Espanyol  ...             -280    0.019504
# 7     8        Real Sociedad  ...               -2    0.017776
# 8     9             Zaragoza  ...             -164    0.014360
# 9    10           Real Betis  ...             -333    0.012468
# 10   11  Deportivo La Coruna  ...             -136    0.011583
# 11   12           Celta Vigo  ...             -346    0.012056
# 12   13           Valladolid  ...             -413    0.009526
# 13   14     Racing Santander  ...             -525    0.009320
# ...

# %%
winpcttop5 =data.sort_values('WinningPct', ascending=False )

# %%
winpcttop5[:5]
#the top 5 teams which has the highest Winning percentage
# Out:
#    Pos             Team  Seasons  ...  BestPosition  Goal_diff_count  WinningPct
# 0    1      Real Madrid       86  ...             1             2807    0.033885
# 1    2        Barcelona       86  ...             1             2786    0.032527
# 2    3  Atletico Madrid       80  ...             1             1225    0.025532
# 4    5  Athletic Bilbao       86  ...             1              931    0.024873
# 3    4         Valencia       82  ...             1              929    0.024421
#
# [5 rows x 22 columns]

# %%
data.groupby(['BestPosition']).agg({'Points':'sum'})
#6.	Group teams based on their “Best position” and print the sum of their points for all positions
# Out:
#               Points
# BestPosition
# 1              27933
# 2               6904
# 3               5221
# 4               6563
# 5               1884
# 6               2113
# 7               1186
# 8               1134
# 9                 96
# 10               450
# 11               445
# 12               511
# 14                71
# 15                14
# 16                81
# 17               266
# 19                81
# 20                34

# %%
data
# Out:
#     Pos                 Team  ...  Goal_diff_count  WinningPct
# 0     1          Real Madrid  ...             2807    0.033885
# 1     2            Barcelona  ...             2786    0.032527
# 2     3      Atletico Madrid  ...             1225    0.025532
# 3     4             Valencia  ...              929    0.024421
# 4     5      Athletic Bilbao  ...              931    0.024873
# 5     6              Sevilla  ...              307    0.020368
# 6     7             Espanyol  ...             -280    0.019504
# 7     8        Real Sociedad  ...               -2    0.017776
# 8     9             Zaragoza  ...             -164    0.014360
# 9    10           Real Betis  ...             -333    0.012468
# 10   11  Deportivo La Coruna  ...             -136    0.011583
# 11   12           Celta Vigo  ...             -346    0.012056
# 12   13           Valladolid  ...             -413    0.009526
# 13   14     Racing Santander  ...             -525    0.009320
# ...
